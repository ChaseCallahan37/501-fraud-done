# %%
import polars as pl
import pathlib
import pandas as pd
import numpy as np

# Classifiers
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import Perceptron, PassiveAggressiveClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import make_classification
from sklearn.metrics import ConfusionMatrixDisplay, precision_score, recall_score, f1_score, confusion_matrix, classification_report

import matplotlib.pyplot as plt
import seaborn as SNS

import pyarrow

import hashlib
from joblib import dump, load
import json

from pprint import pprint as p

from datetime import datetime

# %%
orig_data_file = pathlib.Path("./data/mis501_fraud.csv")

# %%
polars_fraud_df = pl.read_csv(orig_data_file)

polars_fraud_df = polars_fraud_df.with_columns([
    pl.col("date_of_birth").str.strptime(pl.Date, "%d/%m/%Y"),
    pl.col("transaction_timestamp").str.strptime(pl.Datetime, "%d/%m/%Y %H:%M")
])

# %%
current_year = pl.lit(datetime.now().year)

# We want to derive useful data from these dates that our classifier can use
polars_fraud_df = polars_fraud_df.with_columns([
    polars_fraud_df["transaction_timestamp"].dt.hour().alias("transaction_hour"),
    polars_fraud_df["transaction_timestamp"].dt.weekday().alias("transaction_day"),
    (current_year - polars_fraud_df["date_of_birth"].dt.year()).alias("cardholder_age") 
])

# %%
polars_fraud_df = polars_fraud_df.with_columns([
    pl.when(pl.col('gender') == "M").then(1).otherwise(0).alias('gender_encoded')
])

# %%
# I pulled this straight from chat
def haversine(lat1, lon1, lat2, lon2):
    # Radius of the Earth in kilometers
    R = 6371.0
    
    # Convert latitude and longitude from degrees to radians
    phi1 = np.radians(lat1)
    phi2 = np.radians(lat2)
    delta_phi = np.radians(lat2 - lat1)
    delta_lambda = np.radians(lon2 - lon1)
    
    # Haversine formula
    a = np.sin(delta_phi / 2.0) ** 2 + np.cos(phi1) * np.cos(phi2) * np.sin(delta_lambda / 2.0) ** 2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    distance = R * c  # in kilometers
    
    return distance

# %%
# Apply the Haversine function to calculate distances
polars_fraud_df = polars_fraud_df.with_columns(
    pl.apply(
        [pl.col("lat"), pl.col("long"), pl.col("merch_lat"), pl.col("merch_long")],
        lambda cols: haversine(cols[0], cols[1], cols[2], cols[3])
    ).alias("distance_km")
)
# Out:
# /tmp/ipykernel_6196/184009762.py:3: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_groups`.
#   pl.apply(

# %%
target = "is_fraud"

# Grabbing all columns that are numerical
numerical_features = ['amount', 'city_pop', 'transaction_hour', 'transaction_day', 'cardholder_age', 'distance_km', 'gender_encoded']

# Grabbing all columns that represent categorical data
categorical_features= ["category", "job_title"]

# Combining features together 
all_features = numerical_features + categorical_features

# %%
# We only want to retain the columns that will be used in the classifier
polars_fraud_df = polars_fraud_df[[target] + numerical_features]
polars_fraud_df
# Out:
# shape: (416_789, 8)
# ┌──────────┬────────┬──────────┬─────────────┬─────────────┬─────────────┬────────────┬────────────┐
# │ is_fraud ┆ amount ┆ city_pop ┆ transaction ┆ transaction ┆ cardholder_ ┆ distance_k ┆ gender_enc │
# │ ---      ┆ ---    ┆ ---      ┆ _hour       ┆ _day        ┆ age         ┆ m          ┆ oded       │
# │ i64      ┆ f64    ┆ i64      ┆ ---         ┆ ---         ┆ ---         ┆ ---        ┆ ---        │
# │          ┆        ┆          ┆ i8          ┆ i8          ┆ i32         ┆ f64        ┆ i32        │
# ╞══════════╪════════╪══════════╪═════════════╪═════════════╪═════════════╪════════════╪════════════╡
# │ 0        ┆ 1.07   ┆ 5438     ┆ 7           ┆ 7           ┆ 60          ┆ 66.563673  ┆ 0          │
# │ 0        ┆ 94.99  ┆ 7163     ┆ 14          ┆ 7           ┆ 42          ┆ 85.415937  ┆ 1          │
# │ 0        ┆ 31.28  ┆ 602      ┆ 16          ┆ 1           ┆ 70          ┆ 16.266628  ┆ 0          │
# │ 0        ┆ 73.06  ┆ 7163     ┆ 10          ┆ 6           ┆ 42          ┆ 110.434216 ┆ 1          │
# │ 0        ┆ 9.99   ┆ 2036     ┆ 1           ┆ 1           ┆ 53          ┆ 72.330958  ┆ 0          │
# │ …        ┆ …      ┆ …        ┆ …           ┆ …           ┆ …           ┆ …          ┆ …          │
# │ 0        ┆ 80.93  ┆ 3688     ┆ 12          ┆ 6           ┆ 51          ┆ 44.248096  ┆ 1          │
# │ 0        ┆ 102.42 ┆ 54287    ┆ 9           ┆ 6           ┆ 52          ┆ 132.483211 ┆ 0          │
# │ 0        ┆ 84.52  ┆ 7297     ┆ 23          ┆ 4           ┆ 34          ┆ 91.293779  ┆ 1          │
# │ 0        ┆ 244.65 ┆ 51       ┆ 14          ┆ 4           ┆ 64          ┆ 52.277209  ┆ 0          │
# │ 0        ┆ 29.97  ┆ 239      ┆ 13          ┆ 4           ┆ 68          ┆ 76.43618   ┆ 1          │
# └──────────┴────────┴──────────┴─────────────┴─────────────┴─────────────┴────────────┴────────────┘

# %%
# polars_fraud_df = polars_fraud_df.to_dummies(categorical_features)

# %%
# all_features = [col for col in polars_fraud_df.columns if col != target]

# all_features

# %%
dummified_file_name = "./data/dummified-data.csv"
polars_fraud_df.write_csv(dummified_file_name)

# %%
dum_data_file = pathlib.Path(dummified_file_name)

fraud_df = pd.read_csv(dum_data_file)

fraud_df
# Out:
#         is_fraud  amount  city_pop  transaction_hour  transaction_day  \
# 0              0    1.07      5438                 7                7
# 1              0   94.99      7163                14                7
# 2              0   31.28       602                16                1
# 3              0   73.06      7163                10                6
# 4              0    9.99      2036                 1                1
# ...          ...     ...       ...               ...              ...
# 416784         0   80.93      3688                12                6
# 416785         0  102.42     54287                 9                6
# 416786         0   84.52      7297                23                4
# 416787         0  244.65        51                14                4
# 416788         0   29.97       239                13                4
#
#         cardholder_age  distance_km  gender_encoded
# 0                   60    66.563673               0
# 1                   42    85.415937               1
# 2                   70    16.266628               0
# 3                   42   110.434216               1
# 4                   53    72.330958               0
# ...                ...          ...             ...
# 416784              51    44.248096               1
# 416785              52   132.483211               0
# 416786              34    91.293779               1
# 416787              64    52.277209               0
# 416788              68    76.436180               1
#
# [416789 rows x 8 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    fraud_df[numerical_features],
    fraud_df[target],
    test_size=.2,
    random_state=42
)

# %%
def hash_dictionary(d):
    # Sort the dictionary by key to ensure consistent ordering
    serialized = json.dumps(d, sort_keys=True)
    # Create a hash object
    hash_object = hashlib.sha256(serialized.encode())
    # Return the hexadecimal digest of the hash
    return hash_object.hexdigest()

# %%
# Create list of different classifiers for training
base_clfs = [
    {

        "title": "Decision Tree",
        "clf": DecisionTreeClassifier(random_state=42),
        "features": all_features,
        "params": {
            "criterion": ['gini', 'entropy', 'log_loss'],
            'splitter': ['best', 'random'],
            'max_features': [None, 'sqrt', 'log2'],
            'class_weight': [{0:1, 1: n} for n in [1, 5, 8, 10, 12, 15, 20, 25, 30, 50, 60]]
        }
    },
    {
        "title": "Decision Tree 20",
        "clf": DecisionTreeClassifier(random_state=42),
        "features": all_features,
        "params": {
            "criterion": ['gini'],
            'splitter': ['best'],
            'max_depth': [5],
            'max_features': ['sqrt'],
            'class_weight': [{0: 1, 1: 20}]
        }
    },
     {
        "title": "Decision Tree 40",
        "clf": DecisionTreeClassifier(random_state=42),
        "features": all_features,
        "params": {
            "criterion": ['gini'],
            'splitter': ['best'],
            'max_depth': [5],
            'max_features': ['sqrt'],
            'class_weight': [{0: 1, 1: 40}]
        }
    },

 {
        "title": "Decision Tree 60",
        "clf": DecisionTreeClassifier(random_state=42),
        "features": all_features,
        "params": {
            "criterion": ['gini'],
            'splitter': ['best'],
            'max_depth': [5],
            'max_features': ['sqrt'],
            'class_weight': [{0: 1, 1: 60}]
        }
    },

    {
        "title": "Random Forest 20",
        "clf": RandomForestClassifier(random_state=42),
        "features": all_features,
        "params": {
            "n_estimators": [100],
            "max_depth": [5],
            "class_weight": [{0: 1, 1: 20}]
        }
    }, 

{
        "title": "Random Forest 15",
        "clf": RandomForestClassifier(random_state=42),
        "features": all_features,
        "params": {
            "n_estimators": [100],
            "max_depth": [5],
            "class_weight": [{0: 1, 1: 15}]
        }
    },

{
        "title": "Random Forest 25",
        "clf": RandomForestClassifier(random_state=42),
        "features": all_features,
        "params": {
            "n_estimators": [100],
            "max_depth": [5],
            "class_weight": [{0: 1, 1: 25}]
        }
    },
{
        "title": "Random Forest 40",
        "clf": RandomForestClassifier(random_state=42),
        "features": all_features,
        "params": {
            "n_estimators": [100],
            "max_depth": [5],
            "class_weight": [{0: 1, 1: 40}]
        }
    },
{
        "title": "Random Forest 60",
        "clf": RandomForestClassifier(random_state=42),
        "features": all_features,
        "params": {
            "n_estimators": [100],
            "max_depth": [5],
            "class_weight": [{0: 1, 1: 60}]
        }
    },
{
        "title": "Random Forest 100",
        "clf": RandomForestClassifier(random_state=42),
        "features": all_features,
        "params": {
            "n_estimators": [100],
            "max_depth": [5],
            "class_weight": [{0: 1, 1: 100}]
        }
    },

    {
        "title": "Perceptron",
        "clf": Perceptron(random_state=42),
        "features": all_features,
        "params": {
            "class_weight": [{0: 1, 1: 40}]
        }
    },

    {
        "title": "Logistic Regression",
        "clf": LogisticRegression(random_state=42),
        "features": all_features,
        "params": {
            "solver": ["lbfgs"],
            "max_iter": [4000],
            "C": [1e9],
            "class_weight": [{0: 1, 1: 40}]

        },
    }, 
    {
        "title": "ADA Boost",
        "clf": AdaBoostClassifier(random_state=42),
        "features": all_features,
        "params": {
            "n_estimators": [100],
            "algorithm": ["SAMME"]
        }
    },

{
    "title": "Passive Aggressive",
    "clf": PassiveAggressiveClassifier(),
    "features": all_features,
    "params": {
        "class_weight": [{0: 1, 1: 40}]
    }
},

    
    {
        'title': 'KNeighbors',
        'clf': KNeighborsClassifier(),
        'features': all_features,
        'params': {
            'n_neighbors': [2, 3, 4, 5, 6, 7, 8]
        }
    },
    {
        "title": "Artificial Neural Networks",
        "clf": MLPClassifier(random_state=42),
        "features": all_features,
        "params": {
            "hidden_layer_sizes": [(10, 10)],
            "activation": ["relu", 'identity', 'logistic', 'tanh'],
            'solver': ['lbfgs', 'sgd', 'adam'],
            'learning_rate': ['constant', 'invscaling', 'adaptive']
        }
    },

    {
        "title": "Random Forest V2 5",
        "clf": RandomForestClassifier(random_state=42),
        "params": {
            # "class_weight": [{0: 1, 1: n} for n in [1, 5, 10, 15, 20, 30, 40, 50, 60, 70, 80, 90, 100]],
            "class_weight": [{0: 1, 1: 5}],
            "n_estimators": [75],
            "criterion": ["entropy"],
            "max_features": [None],
        }
    },
{
        "title": "Random Forest V2 10",
        "clf": RandomForestClassifier(random_state=42),
        "params": {
            # "class_weight": [{0: 1, 1: n} for n in [1, 5, 10, 15, 20, 30, 40, 50, 60, 70, 80, 90, 100]],
            "class_weight": [{0: 1, 1: 10}],
            "n_estimators": [75],
            "criterion": ["entropy"],
            "max_features": [None],
        }
    },
{
        "title": "Random Forest V2 15",
        "clf": RandomForestClassifier(random_state=42),
        "params": {
            # "class_weight": [{0: 1, 1: n} for n in [1, 5, 10, 15, 20, 30, 40, 50, 60, 70, 80, 90, 100]],
            "class_weight": [{0: 1, 1: 15}],
            "n_estimators": [75],
            "criterion": ["entropy"],
            "max_features": [None],
        }
    },

 {
        "title": "Random Forest V2 20",
        "clf": RandomForestClassifier(random_state=42),
        "params": {
            # "class_weight": [{0: 1, 1: n} for n in [1, 5, 10, 15, 20, 30, 40, 50, 60, 70, 80, 90, 100]],
            "class_weight": [{0: 1, 1: 20}],
            "n_estimators": [75],
            "criterion": ["entropy"],
            "max_features": [None],
        }
    },


 {
        "title": "Random Forest V2 40",
        "clf": RandomForestClassifier(random_state=42),
        "params": {
            # "class_weight": [{0: 1, 1: n} for n in [1, 5, 10, 15, 20, 30, 40, 50, 60, 70, 80, 90, 100]],
            "class_weight": [{0: 1, 1: 40}],
            "n_estimators": [75],
            "criterion": ["entropy"],
            "max_features": [None],
        }
    },

{
        "title": "Random Forest Perf",
        "clf": RandomForestClassifier(random_state=42),
        "params": {
            # "class_weight": [{0: 1, 1: n} for n in [1, 5, 10, 15, 20, 30, 40, 50, 60, 70, 80, 90, 100]],
            "class_weight": [{0: 1, 1: n} for n in [6, 7, 8, 9, 10, 11, 12, 13, 14]],
            "n_estimators": [75],
            "criterion": ["entropy"],
            "max_features": [None],
        }
    },

    {
        "title": "Random Forest Perf V2",
        "clf": RandomForestClassifier(random_state=42),
        "params": {
            # "class_weight": [{0: 1, 1: n} for n in [1, 5, 10, 15, 20, 30, 40, 50, 60, 70, 80, 90, 100]],
            "class_weight": [{0: 1, 1: n} for n in range(50, 125, 5)],
            "n_estimators": [75],
            "criterion": ["entropy"],
            "max_features": [None],
        }
    },

{
        "title": "Gradient Boosting",
        "clf": GradientBoostingClassifier(random_state=42),
        "features": all_features,
        "params": {
            "n_estimators": [100, 200, 300],
            "min_samples_split": [2, 3],
            "min_samples_leaf": [1, 2],
            "learning_rate": [0.01, 0.05, 0.1, 0.2],
            # Using exponential because we want the model to be more sensitive to mis-classifications.
            "loss": ["exponential"],
            # Using this becuse it is specifically designed for gradient boosting
            "criterion": ['friedman_mse'],
            # Using none since there is a relatively low number of features that are used
            "max_features": [None]
        },
    },

]

def load_clf(file_hash: str):
    try:
        return load(f"./clfs/{file_hash}.joblib")
    except:
        return None

def save_clf(file_name: str, clf: GridSearchCV):
    dump(clf, f"./clfs/{file_name}.joblib")


def run_gridsearch(base_clf: dict):
    # retrieve the params to be used for GridSearch
    params = base_clf['params']

    min_base_clf = base_clf.copy()
    del min_base_clf['clf']
    
    # Hash the params to create unique file id
    min_base_clf_hash = hash_dictionary(min_base_clf)

    # Attempt to load the clf if params have not changed
    clf = load_clf(min_base_clf_hash)

    # Dumpt the clf to a file to save time for future testing
    if clf == None:

        # Instantiate the GridSearch object
        clf = GridSearchCV(base_clf['clf'], param_grid=params, n_jobs=7, scoring="recall")
        
        # fit the model
        clf = clf.fit(X_train, y_train)

        # dump  the model to the file for caching
        save_clf(min_base_clf_hash, clf)

    # return necessary data for future processing
    return {
        "clf": clf,
        "title": base_clf['title']
    }


# Train each classifier specified
trained_clfs = [run_gridsearch(base_clf) for base_clf in base_clfs]

# %%
trained_clfs[-1]["clf"].best_params_
# Out:
# {'class_weight': {0: 1, 1: 60},
#  'criterion': 'entropy',
#  'max_features': None,
#  'n_estimators': 75}

# %%
def gather_classification_results(trained_clf: GridSearchCV, data: pd.DataFrame):
    title = trained_clf['title']
    clf = trained_clf['clf']

    # Calculate training and testing scores
    training_score = clf.score(X_train, y_train)
    testing_score = clf.score(X_test, y_test)

    # Make predictions on the test data
    predictions = clf.predict(X_test)

    # Calculate accuracy, precision, recall, and F1 score
    accuracy = (predictions == y_test).mean()
    precision = precision_score(y_test, predictions, average='binary')
    recall = recall_score(y_test, predictions, average='binary')
    f1 = f1_score(y_test, predictions, average='binary')

    cm = confusion_matrix(y_test, predictions)
    tn, fp, fn, tp = cm.ravel()

    # Calculate the false negative and false positive rates
    false_negative_rate = fn / (fn + tp) * 100
    false_positive_rate = fp / (fp + tn) * 100

   # Calculate fraud_pred_accuracy, i.e., recall or true positive rate
    fraud_pred_accuracy = tp / (tp + fn) * 100

    return {
        "title": title,
        "training_score": training_score * 100,
        "testing_score": testing_score * 100,
        "accuracy": accuracy * 100,
        "precision": precision * 100,
        "recall": recall * 100,
        "f1_score": f1 * 100,
        "false_negative_rate": false_negative_rate,
        "false_positive_rate": false_positive_rate,
        "fraud_pred_accuracy": fraud_pred_accuracy,
        "matrix": [[tn, fp], [fn, tp]]
    }

# %%
results = [gather_classification_results(trained_clf, fraud_df.copy()) for trained_clf in trained_clfs]
sorted_results = sorted(results, key=lambda x: x['recall'], reverse=True)
sorted_results
# Out:
# [{'title': 'Random Forest 100',
#   'training_score': 74.01998462720984,
#   'testing_score': 71.2166172106825,
#   'accuracy': 97.5227332709518,
#   'precision': 10.869565217391305,
#   'recall': 71.2166172106825,
#   'f1_score': 18.86051080550098,
#   'false_negative_rate': 28.783382789317507,
#   'false_positive_rate': 2.3704845761915663,
#   'fraud_pred_accuracy': 71.2166172106825,
#   'matrix': [[81053, 1968], [97, 240]]},
#  {'title': 'Random Forest 60',
#   'training_score': 73.55880092236741,
#   'testing_score': 70.91988130563797,
#   'accuracy': 97.89942177115574,
#   'precision': 12.63213530655391,
#   'recall': 70.91988130563797,
#   'f1_score': 21.444593988335573,
#   'false_negative_rate': 29.080118694362017,
#   'false_positive_rate': 1.9910625022584647,
#   'fraud_pred_accuracy': 70.91988130563797,
#   'matrix': [[81368, 1653], [98, 239]]},
#  {'title': 'Random Forest 40',
#   'training_score': 72.09838585703305,
#   'testing_score': 69.43620178041543,
#   'accuracy': 98.80275438470213,
#   'precision': 20.726306465899025,
#   'recall': 69.43620178041543,
#   'f1_score': 31.923601637107772,
#   'false_negative_rate': 30.56379821958457,
#   'false_positive_rate': 1.0780404957781766,
#   'fraud_pred_accuracy': 69.43620178041543,
#   'matrix': [[82126, 895], [103, 234]]},
#  {'title': 'Decision Tree 60',
#   'training_score': 73.0207532667179,
#   'testing_score': 68.84272997032642,
#   'accuracy': 97.48434463398834,
#   'precision': 10.431654676258994,
#   'recall': 68.84272997032642,
#   'f1_score': 18.11792268645061,
#   'false_negative_rate': 31.15727002967359,
#   'false_positive_rate': 2.399392924681707,
#   'fraud_pred_accuracy': 68.84272997032642,
#   'matrix': [[81029, 1992], [105, 232]]},
#  {'title': 'Random Forest 25',
#   'training_score': 68.48578016910069,
#   'testing_score': 67.35905044510386,
#   'accuracy': 99.25262122411766,
#   'precision': 30.675675675675674,
#   'recall': 67.35905044510386,
#   'f1_score': 42.154131847725154,
#   'false_negative_rate': 32.640949554896146,
#   'false_positive_rate': 0.6179159489767649,
#   'fraud_pred_accuracy': 67.35905044510386,
#   'matrix': [[82508, 513], [110, 227]]},
#  {'title': 'Random Forest 20',
#   'training_score': 67.48654880860876,
#   'testing_score': 64.98516320474778,
#   'accuracy': 99.35099210633652,
#   'precision': 34.112149532710276,
#   'recall': 64.98516320474778,
#   'f1_score': 44.73953013278856,
#   'false_negative_rate': 35.01483679525222,
#   'false_positive_rate': 0.5095096421387361,
#   'fraud_pred_accuracy': 64.98516320474778,
#   'matrix': [[82598, 423], [118, 219]]},
#  {'title': 'Decision Tree 40',
#   'training_score': 62.49039200614912,
#   'testing_score': 63.798219584569736,
#   'accuracy': 99.19863720338779,
#   'precision': 28.252299605781868,
#   'recall': 63.798219584569736,
#   'f1_score': 39.162112932604735,
#   'false_negative_rate': 36.20178041543027,
#   'false_positive_rate': 0.6576649281507089,
#   'fraud_pred_accuracy': 63.798219584569736,
#   'matrix': [[82475, 546], [122, 215]]},
#  {'title': 'Random Forest 15',
#   'training_score': 66.0261337432744,
#   'testing_score': 62.01780415430267,
#   'accuracy': 99.51414381343122,
#   'precision': 43.00411522633745,
#   'recall': 62.01780415430267,
#   'f1_score': 50.78979343863913,
#   'false_negative_rate': 37.98219584569733,
#   'false_positive_rate': 0.3336505221570446,
#   'fraud_pred_accuracy': 62.01780415430267,
#   'matrix': [[82744, 277], [128, 209]]},
#  {'title': 'Decision Tree 20',
#   'training_score': 61.029976940814755,
#   'testing_score': 61.72106824925816,
#   'accuracy': 99.26101873845342,
#   'precision': 29.928057553956833,
#   'recall': 61.72106824925816,
#   'f1_score': 40.310077519379846,
#   'false_negative_rate': 38.27893175074184,
#   'false_positive_rate': 0.5865985714457788,
#   'fraud_pred_accuracy': 61.72106824925816,
#   'matrix': [[82534, 487], [129, 208]]},
#  {'title': 'Perceptron',
#   'training_score': 52.49807840122982,
#   'testing_score': 54.59940652818991,
#   'accuracy': 95.36937066628278,
#   'precision': 4.728861475199177,
#   'recall': 54.59940652818991,
#   'f1_score': 8.703878902554399,
#   'false_negative_rate': 45.40059347181009,
#   'false_positive_rate': 4.46513532720637,
#   'fraud_pred_accuracy': 54.59940652818991,
#   'matrix': [[79314, 3707], [153, 184]]},
#  {'title': 'Random Forest V2 10',
#   'training_score': 99.76940814757879,
#   'testing_score': 53.70919881305638,
#   'accuracy': 99.77086782312435,
#   'precision': 83.79629629629629,
#   'recall': 53.70919881305638,
#   'f1_score': 65.4611211573237,
#   'false_negative_rate': 46.29080118694362,
#   'false_positive_rate': 0.04215800821478903,
#   'fraud_pred_accuracy': 53.70919881305638,
#   'matrix': [[82986, 35], [156, 181]]},
#  {'title': 'Decision Tree',
#   'training_score': 100.0,
#   'testing_score': 53.41246290801187,
#   'accuracy': 99.62451114470116,
#   'precision': 53.57142857142857,
#   'recall': 53.41246290801187,
#   'f1_score': 53.49182763744428,
#   'false_negative_rate': 46.58753709198813,
#   'false_positive_rate': 0.18790426518591682,
#   'fraud_pred_accuracy': 53.41246290801187,
#   'matrix': [[82865, 156], [157, 180]]},
#  {'title': 'Random Forest V2 15',
#   'training_score': 99.84627209838585,
#   'testing_score': 52.818991097922854,
#   'accuracy': 99.76846853331413,
#   'precision': 83.9622641509434,
#   'recall': 52.818991097922854,
#   'f1_score': 64.84517304189436,
#   'false_negative_rate': 47.18100890207715,
#   'false_positive_rate': 0.04095349369436649,
#   'fraud_pred_accuracy': 52.818991097922854,
#   'matrix': [[82987, 34], [159, 178]]},
#  {'title': 'Random Forest V2 20',
#   'training_score': 99.76940814757879,
#   'testing_score': 52.818991097922854,
#   'accuracy': 99.77566640274479,
#   'precision': 86.40776699029125,
#   'recall': 52.818991097922854,
#   'f1_score': 65.56169429097606,
#   'false_negative_rate': 47.18100890207715,
#   'false_positive_rate': 0.03372640657183122,
#   'fraud_pred_accuracy': 52.818991097922854,
#   'matrix': [[82993, 28], [159, 178]]},
#  {'title': 'Random Forest Perf',
#   'training_score': 99.84627209838585,
#   'testing_score': 52.818991097922854,
#   'accuracy': 99.76846853331413,
#   'precision': 83.9622641509434,
#   'recall': 52.818991097922854,
#   'f1_score': 64.84517304189436,
#   'false_negative_rate': 47.18100890207715,
#   'false_positive_rate': 0.04095349369436649,
#   'fraud_pred_accuracy': 52.818991097922854,
#   'matrix': [[82987, 34], [159, 178]]},
#  {'title': 'Random Forest Perf V2',
#   'training_score': 99.76940814757879,
#   'testing_score': 52.22551928783383,
#   'accuracy': 99.76846853331413,
#   'precision': 84.61538461538461,
#   'recall': 52.22551928783383,
#   'f1_score': 64.58715596330276,
#   'false_negative_rate': 47.774480712166174,
#   'false_positive_rate': 0.0385444646535214,
#   'fraud_pred_accuracy': 52.22551928783383,
#   'matrix': [[82989, 32], [161, 176]]},
#  {'title': 'Random Forest V2 5',
#   'training_score': 99.76940814757879,
#   'testing_score': 51.92878338278932,
#   'accuracy': 99.76486959859882,
#   'precision': 83.73205741626795,
#   'recall': 51.92878338278932,
#   'f1_score': 64.1025641025641,
#   'false_negative_rate': 48.07121661721068,
#   'false_positive_rate': 0.04095349369436649,
#   'fraud_pred_accuracy': 51.92878338278932,
#   'matrix': [[82987, 34], [162, 175]]},
#  {'title': 'Random Forest V2 40',
#   'training_score': 99.76940814757879,
#   'testing_score': 51.92878338278932,
#   'accuracy': 99.76966817821925,
#   'precision': 85.36585365853658,
#   'recall': 51.92878338278932,
#   'f1_score': 64.57564575645758,
#   'false_negative_rate': 48.07121661721068,
#   'false_positive_rate': 0.03613543561267631,
#   'fraud_pred_accuracy': 51.92878338278932,
#   'matrix': [[82991, 30], [162, 175]]},
#  {'title': 'Logistic Regression',
#   'training_score': 50.80707148347425,
#   'testing_score': 50.74183976261127,
#   'accuracy': 98.53523357086303,
#   'precision': 13.947797716150081,
#   'recall': 50.74183976261127,
#   'f1_score': 21.8809980806142,
#   'false_negative_rate': 49.25816023738873,
#   'false_positive_rate': 1.2707628190457836,
#   'fraud_pred_accuracy': 50.74183976261127,
#   'matrix': [[81966, 1055], [166, 171]]},
#  {'title': 'Passive Aggressive',
#   'training_score': 46.34896233666411,
#   'testing_score': 47.774480712166174,
#   'accuracy': 96.70817438038341,
#   'precision': 5.899596921949432,
#   'recall': 47.774480712166174,
#   'f1_score': 10.502283105022832,
#   'false_negative_rate': 52.22551928783383,
#   'false_positive_rate': 3.093193288445092,
#   'fraud_pred_accuracy': 47.774480712166174,
#   'matrix': [[80453, 2568], [176, 161]]},
#  {'title': 'Gradient Boosting',
#   'training_score': 47.501921598770174,
#   'testing_score': 45.99406528189911,
#   'accuracy': 99.74567528011708,
#   'precision': 83.78378378378379,
#   'recall': 45.99406528189911,
#   'f1_score': 59.38697318007663,
#   'false_negative_rate': 54.00593471810089,
#   'false_positive_rate': 0.03613543561267631,
#   'fraud_pred_accuracy': 45.99406528189911,
#   'matrix': [[82991, 30], [182, 155]]},
#  {'title': 'KNeighbors',
#   'training_score': 50.57647963105304,
#   'testing_score': 29.376854599406528,
#   'accuracy': 99.57412605868663,
#   'precision': 45.83333333333333,
#   'recall': 29.376854599406528,
#   'f1_score': 35.80470162748644,
#   'false_negative_rate': 70.62314540059347,
#   'false_positive_rate': 0.1409281988894376,
#   'fraud_pred_accuracy': 29.376854599406528,
#   'matrix': [[82904, 117], [238, 99]]},
#  {'title': 'ADA Boost',
#   'training_score': 27.901614142966945,
#   'testing_score': 27.89317507418398,
#   'accuracy': 99.6748962307157,
#   'precision': 77.04918032786885,
#   'recall': 27.89317507418398,
#   'f1_score': 40.95860566448802,
#   'false_negative_rate': 72.10682492581603,
#   'false_positive_rate': 0.03372640657183122,
#   'fraud_pred_accuracy': 27.89317507418398,
#   'matrix': [[82993, 28], [243, 94]]},
#  {'title': 'Artificial Neural Networks',
#   'training_score': 13.604919292851653,
#   'testing_score': 15.727002967359049,
#   'accuracy': 77.74058878571942,
#   'precision': 0.28923815760750926,
#   'recall': 15.727002967359049,
#   'f1_score': 0.5680295804083382,
#   'false_negative_rate': 84.27299703264094,
#   'false_positive_rate': 22.007684802640295,
#   'fraud_pred_accuracy': 15.727002967359049,
#   'matrix': [[64750, 18271], [284, 53]]}]

# %%
models = list(map(lambda x: [x['clf'], x['title']], trained_clfs))

model_list = list(map(lambda x: x[0], models))
titles = list(map(lambda x: x[1], models))

fig, axes = plt.subplots(14, 2, figsize=(20, 30))  # Adjusted for 6 models, reshaped into a 3x2 grid
axes = axes.flatten()

for ax, model, title in zip(axes, model_list, titles):
    ConfusionMatrixDisplay.from_estimator(
        model,
        X_test, 
        y_test,
        ax=ax,
        cmap='viridis'  # Optional: choose a colormap
    )
    ax.title.set_text(title)  # Set the title for each subplot

plt.tight_layout()
plt.show()
